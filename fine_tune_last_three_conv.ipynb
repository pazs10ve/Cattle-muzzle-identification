# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from torchvision.transforms import v2
from ultralytics import YOLO
from models import get_finetuned_resnet50_last_three_convs
from loaders import get_loaders
from train import train
# Out:
# c:\Users\sharm\Python Projects\Research Papers\Cattle Muzzle Identification\.venv\Lib\site-packages\torchvision\transforms\v2\_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(

# %%
img_width = 224
img_height = 224
batch_size = 64
num_classes = 300
lr = 0.0001

# %%
root_dir = 'cattle muzzle'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
yolo_model = YOLO('yolov10_fine_tuned.pt').to(device)
device
# Out:
# device(type='cuda')

# %%
transform = v2.Compose([
    v2.ToTensor(),
    v2.Resize((img_width, img_height))
])


train_loader, val_loader = get_loaders(root_dir = root_dir, 
                                       model = yolo_model, 
                                       batch_size = batch_size, 
                                       train_ratio=0.5,
                                       transform = transform)

# %%
clf_model = get_finetuned_resnet50_last_three_convs(num_classes).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(clf_model.parameters(), lr=lr)
num_epochs = 40

# %%
train(clf_model, train_loader, val_loader, criterion, optimizer, num_epochs, device)
# Out:
# Epoch 1/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 1/40 --> Training Loss: 5.6942, Training Accuracy: 0.63%
#
# Epoch 2/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 2/40 --> Training Loss: 5.4804, Training Accuracy: 6.19%
#
# Epoch 3/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 3/40 --> Training Loss: 5.2452, Training Accuracy: 13.98%
#
# Epoch 4/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 4/40 --> Training Loss: 4.9630, Training Accuracy: 19.61%
#
# Epoch 5/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 5/40 --> Training Loss: 4.6600, Training Accuracy: 30.53%
#
# Epoch 6/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 6/40 --> Training Loss: 4.3157, Training Accuracy: 43.25%
#
# Epoch 7/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 7/40 --> Training Loss: 3.9739, Training Accuracy: 56.19%
#
# Epoch 8/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 8/40 --> Training Loss: 3.6048, Training Accuracy: 66.62%
#
# Epoch 9/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 9/40 --> Training Loss: 3.2763, Training Accuracy: 74.27%
#
# Epoch 10/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 10/40 --> Training Loss: 2.9395, Training Accuracy: 81.02%
#
# Epoch 11/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 11/40 --> Training Loss: 2.6427, Training Accuracy: 85.19%
#
# Epoch 12/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 12/40 --> Training Loss: 2.3639, Training Accuracy: 88.94%
#
# Epoch 13/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 13/40 --> Training Loss: 2.1233, Training Accuracy: 90.61%
#
# Epoch 14/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 14/40 --> Training Loss: 1.8753, Training Accuracy: 92.07%
#
# Epoch 15/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 15/40 --> Training Loss: 1.6278, Training Accuracy: 93.67%
#
# Epoch 16/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 16/40 --> Training Loss: 1.4426, Training Accuracy: 95.20%
#
# Epoch 17/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 17/40 --> Training Loss: 1.2577, Training Accuracy: 97.29%
#
# Epoch 18/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 18/40 --> Training Loss: 1.1018, Training Accuracy: 96.52%
#
# Epoch 19/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 19/40 --> Training Loss: 0.9462, Training Accuracy: 97.57%
#
# Epoch 20/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 20/40 --> Training Loss: 0.8110, Training Accuracy: 97.84%
#
# Epoch 21/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 21/40 --> Training Loss: 0.7053, Training Accuracy: 98.47%
#
# Epoch 22/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 22/40 --> Training Loss: 0.5867, Training Accuracy: 98.68%
#
# Epoch 23/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 23/40 --> Training Loss: 0.5180, Training Accuracy: 99.03%
#
# Epoch 24/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 24/40 --> Training Loss: 0.4645, Training Accuracy: 99.10%
#
# Epoch 25/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 25/40 --> Training Loss: 0.3897, Training Accuracy: 99.10%
#
# Epoch 26/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 26/40 --> Training Loss: 0.3387, Training Accuracy: 99.44%
#
# Epoch 27/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 27/40 --> Training Loss: 0.2866, Training Accuracy: 99.51%
#
# Epoch 28/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 28/40 --> Training Loss: 0.2498, Training Accuracy: 99.44%
#
# Epoch 29/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 29/40 --> Training Loss: 0.2170, Training Accuracy: 99.65%
#
# Epoch 30/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 30/40 --> Training Loss: 0.2016, Training Accuracy: 99.72%
#
# Epoch 31/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 31/40 --> Training Loss: 0.1698, Training Accuracy: 99.86%
#
# Epoch 32/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 32/40 --> Training Loss: 0.1514, Training Accuracy: 99.93%
#
# Epoch 33/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 33/40 --> Training Loss: 0.1388, Training Accuracy: 99.93%
#
# Epoch 34/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 34/40 --> Training Loss: 0.1265, Training Accuracy: 100.00%
#
# Epoch 35/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 35/40 --> Training Loss: 0.1067, Training Accuracy: 100.00%
#
# Epoch 36/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 36/40 --> Training Loss: 0.1049, Training Accuracy: 100.00%
#
# Epoch 37/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 37/40 --> Training Loss: 0.0982, Training Accuracy: 100.00%
#
# Epoch 38/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 38/40 --> Training Loss: 0.0854, Training Accuracy: 100.00%
#
# Epoch 39/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 39/40 --> Training Loss: 0.0817, Training Accuracy: 100.00%
#
# Epoch 40/40
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 40/40 --> Training Loss: 0.0703, Training Accuracy: 100.00%
#
# Evaluating model on validation set...
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
#
# Final Results after 40 epochs:
# Training Loss: 0.0703, Training Accuracy: 100.00%
# Validation Loss: 1.4619, Validation Accuracy: 82.56%

# %%
torch.save(clf_model, 'resnet_fine_tuned_last_three_conv.pth')

# %%
from PIL import Image

def inference(img_path, transform, yolo_model, clf_model, device):
    img = Image.open(img_path)
    img_tensor = transform(img)

    results = yolo_model(img_tensor)  

    if len(results) > 0:
        bbox = results[0].boxes.xyxy[0] 

        xmin, ymin, xmax, ymax = map(int, bbox)
        cropped_img = img.crop((xmin, ymin, xmax, ymax))

        cropped_img_tensor = transform(cropped_img)
        cropped_img_tensor = cropped_img_tensor.to(device)
        cropped_img_tensor = cropped_img_tensor.unsqueeze(0) 

        output = clf_model(cropped_img_tensor)
        return torch.argmax(output).item()

# %%
img_path = r'cattle muzzle\069\IMG_0906.JPG'
transform = v2.Compose([
    v2.ToTensor(),
    v2.Resize((img_width, img_height))
])
yolo_model = YOLO('yolov10_fine_tuned.pt')
clf_model = torch.load('resnet_transfer_learning.pth')
print(inference(img_path, transform, yolo_model, clf_model, device))
# Out:
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 224, 224) is incompatible.
# 0: 224x224 1 muzzle, 37.7ms
# Speed: 0.0ms preprocess, 37.7ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 224)
# 203
