# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from torchvision.transforms import v2
from ultralytics import YOLO
from models import get_resnet50
from loaders import get_loaders
from train import train
# Out:
# c:\Users\sharm\Python Projects\Research Papers\Cattle Muzzle Identification\.venv\Lib\site-packages\torchvision\transforms\v2\_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(

# %%
img_width = 224
img_height = 224
batch_size = 64
num_classes = 300
lr = 0.0001

# %%
root_dir = 'cattle muzzle'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
yolo_model = YOLO('yolov10_fine_tuned.pt').to(device)
device
# Out:
# device(type='cuda')

# %%
transform = v2.Compose([
    v2.ToTensor(),
    v2.Resize((img_width, img_height))
])


train_loader, val_loader = get_loaders(root_dir = root_dir, 
                                       model = yolo_model, 
                                       batch_size = batch_size, 
                                       train_ratio=0.5,
                                       transform = transform)

# %%
clf_model = get_resnet50(num_classes).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(clf_model.parameters(), lr=lr)
num_epochs = 25

# %%
train(clf_model, train_loader, val_loader, criterion, optimizer, num_epochs, device)
# Out:
# Epoch 1/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 1/25 --> Training Loss: 5.7026, Training Accuracy: 0.63%
#
# Epoch 2/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 2/25 --> Training Loss: 5.6929, Training Accuracy: 1.74%
#
# Epoch 3/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 3/25 --> Training Loss: 5.6779, Training Accuracy: 3.34%
#
# Epoch 4/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 4/25 --> Training Loss: 5.6554, Training Accuracy: 5.42%
#
# Epoch 5/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 5/25 --> Training Loss: 5.6592, Training Accuracy: 5.08%
#
# Epoch 6/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 6/25 --> Training Loss: 5.6629, Training Accuracy: 4.80%
#
# Epoch 7/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 7/25 --> Training Loss: 5.6474, Training Accuracy: 6.19%
#
# Epoch 8/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 8/25 --> Training Loss: 5.6491, Training Accuracy: 6.12%
#
# Epoch 9/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 9/25 --> Training Loss: 5.6497, Training Accuracy: 5.91%
#
# Epoch 10/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 10/25 --> Training Loss: 5.6396, Training Accuracy: 7.16%
#
# Epoch 11/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 11/25 --> Training Loss: 5.6329, Training Accuracy: 7.65%
#
# Epoch 12/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 12/25 --> Training Loss: 5.6337, Training Accuracy: 7.58%
#
# Epoch 13/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 13/25 --> Training Loss: 5.6294, Training Accuracy: 8.07%
#
# Epoch 14/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 14/25 --> Training Loss: 5.6280, Training Accuracy: 8.14%
#
# Epoch 15/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 15/25 --> Training Loss: 5.6234, Training Accuracy: 8.83%
#
# Epoch 16/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 16/25 --> Training Loss: 5.6196, Training Accuracy: 8.90%
#
# Epoch 17/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 17/25 --> Training Loss: 5.6275, Training Accuracy: 8.41%
#
# Epoch 18/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 18/25 --> Training Loss: 5.6179, Training Accuracy: 9.67%
#
# Epoch 19/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 19/25 --> Training Loss: 5.6132, Training Accuracy: 9.87%
#
# Epoch 20/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 20/25 --> Training Loss: 5.6061, Training Accuracy: 10.50%
#
# Epoch 21/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 21/25 --> Training Loss: 5.6040, Training Accuracy: 10.78%
#
# Epoch 22/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 22/25 --> Training Loss: 5.5979, Training Accuracy: 11.27%
#
# Epoch 23/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 23/25 --> Training Loss: 5.5939, Training Accuracy: 11.96%
#
# Epoch 24/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 24/25 --> Training Loss: 5.5890, Training Accuracy: 12.38%
#
# Epoch 25/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Epoch 25/25 --> Training Loss: 5.5879, Training Accuracy: 12.45%
#
# Evaluating model on validation set...
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
#
# Final Results after 25 epochs:
# Training Loss: 5.5879, Training Accuracy: 12.45%
# Validation Loss: 5.6555, Validation Accuracy: 5.42%

# %%
torch.save(clf_model, 'resnet_scratch.pth')

# %%
from PIL import Image

def inference(img_path, transform, yolo_model, clf_model, device):
    img = Image.open(img_path)
    img_tensor = transform(img)

    results = yolo_model(img_tensor)  

    if len(results) > 0:
        bbox = results[0].boxes.xyxy[0] 

        xmin, ymin, xmax, ymax = map(int, bbox)
        cropped_img = img.crop((xmin, ymin, xmax, ymax))

        cropped_img_tensor = transform(cropped_img)
        cropped_img_tensor = cropped_img_tensor.to(device)
        cropped_img_tensor = cropped_img_tensor.unsqueeze(0) 

        output = clf_model(cropped_img_tensor)
        return torch.argmax(output).item()

# %%
img_path = r'cattle muzzle\069\IMG_0906.JPG'
transform = v2.Compose([
    v2.ToTensor(),
    v2.Resize((img_width, img_height))
])
yolo_model = YOLO('yolov10_fine_tuned.pt')
clf_model = torch.load('resnet_transfer_learning.pth')
print(inference(img_path, transform, yolo_model, clf_model, device))
# Out:
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 224, 224) is incompatible.
# 0: 224x224 1 muzzle, 44.7ms
# Speed: 0.0ms preprocess, 44.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# 203
