# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from torchvision.transforms import v2
from ultralytics import YOLO
from models import get_resnet50
from loaders import get_loaders
from train import train
# Out:
# c:\Users\sharm\Python Projects\Research Papers\Cattle Muzzle Identification\.venv\Lib\site-packages\torchvision\transforms\v2\_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(

# %%
img_width = 224
img_height = 224
batch_size = 64
num_classes = 300
lr = 0.0001

# %%
root_dir = 'cattle muzzle'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
yolo_model = YOLO('yolov10_fine_tuned.pt').to(device)
device
# Out:
# device(type='cuda')

# %%
transform = v2.Compose([
    v2.ToTensor(),
    v2.Resize((img_width, img_height))
])


train_loader, val_loader = get_loaders(root_dir = root_dir, 
                                       model = yolo_model, 
                                       batch_size = batch_size, 
                                       train_ratio=0.5,
                                       transform = transform)

# %%
clf_model = get_resnet50(num_classes).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(clf_model.parameters(), lr=lr)
num_epochs = 25

# %%
train(clf_model, train_loader, val_loader, criterion, optimizer, num_epochs, device)
# Out:
# Epoch 1/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 1/25 --> Training Loss: 5.8667, Training Accuracy: 0.70%, Validation Loss: 5.8610, Validation Accuracy: 0.28%
#
# Epoch 2/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 2/25 --> Training Loss: 5.3155, Training Accuracy: 2.92%, Validation Loss: 6.1791, Validation Accuracy: 0.28%
#
# Epoch 3/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 3/25 --> Training Loss: 4.7987, Training Accuracy: 9.46%, Validation Loss: 5.1386, Validation Accuracy: 5.14%
#
# Epoch 4/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 4/25 --> Training Loss: 4.1347, Training Accuracy: 18.57%, Validation Loss: 4.3405, Validation Accuracy: 14.80%
#
# Epoch 5/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 5/25 --> Training Loss: 3.4318, Training Accuracy: 30.39%, Validation Loss: 3.9456, Validation Accuracy: 19.18%
#
# Epoch 6/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 6/25 --> Training Loss: 2.8159, Training Accuracy: 45.20%, Validation Loss: 3.3821, Validation Accuracy: 30.92%
#
# Epoch 7/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 7/25 --> Training Loss: 2.2110, Training Accuracy: 58.62%, Validation Loss: 3.0357, Validation Accuracy: 39.75%
#
# Epoch 8/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 8/25 --> Training Loss: 1.7273, Training Accuracy: 70.65%, Validation Loss: 2.7896, Validation Accuracy: 44.61%
#
# Epoch 9/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 9/25 --> Training Loss: 1.2530, Training Accuracy: 83.73%, Validation Loss: 2.6277, Validation Accuracy: 47.46%
#
# Epoch 10/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 10/25 --> Training Loss: 0.9590, Training Accuracy: 89.36%, Validation Loss: 2.2382, Validation Accuracy: 60.11%
#
# Epoch 11/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 11/25 --> Training Loss: 0.7189, Training Accuracy: 93.67%, Validation Loss: 2.2842, Validation Accuracy: 55.46%
#
# Epoch 12/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 12/25 --> Training Loss: 0.4890, Training Accuracy: 96.66%, Validation Loss: 1.8059, Validation Accuracy: 69.91%
#
# Epoch 13/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 13/25 --> Training Loss: 0.3112, Training Accuracy: 98.82%, Validation Loss: 1.7709, Validation Accuracy: 70.33%
#
# Epoch 14/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 14/25 --> Training Loss: 0.2159, Training Accuracy: 99.72%, Validation Loss: 1.5319, Validation Accuracy: 74.77%
#
# Epoch 15/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 15/25 --> Training Loss: 0.1424, Training Accuracy: 99.86%, Validation Loss: 1.4685, Validation Accuracy: 76.51%
#
# Epoch 16/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 16/25 --> Training Loss: 0.0978, Training Accuracy: 99.79%, Validation Loss: 1.3629, Validation Accuracy: 77.21%
#
# Epoch 17/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 17/25 --> Training Loss: 0.0736, Training Accuracy: 100.00%, Validation Loss: 1.3614, Validation Accuracy: 77.35%
#
# Epoch 18/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 18/25 --> Training Loss: 0.0653, Training Accuracy: 99.86%, Validation Loss: 1.3024, Validation Accuracy: 78.94%
#
# Epoch 19/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 19/25 --> Training Loss: 0.0547, Training Accuracy: 100.00%, Validation Loss: 1.3337, Validation Accuracy: 77.90%
#
# Epoch 20/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 20/25 --> Training Loss: 0.0505, Training Accuracy: 99.93%, Validation Loss: 1.3032, Validation Accuracy: 77.90%
#
# Epoch 21/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 21/25 --> Training Loss: 0.0316, Training Accuracy: 100.00%, Validation Loss: 1.2647, Validation Accuracy: 79.22%
#
# Epoch 22/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 22/25 --> Training Loss: 0.0305, Training Accuracy: 100.00%, Validation Loss: 1.2239, Validation Accuracy: 79.92%
#
# Epoch 23/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 23/25 --> Training Loss: 0.0398, Training Accuracy: 99.86%, Validation Loss: 1.2912, Validation Accuracy: 78.46%
#
# Epoch 24/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 24/25 --> Training Loss: 0.0261, Training Accuracy: 100.00%, Validation Loss: 1.2079, Validation Accuracy: 79.43%
#
# Epoch 25/25
# Training batch 1/23
# Training batch 2/23
# Training batch 3/23
# Training batch 4/23
# Training batch 5/23
# Training batch 6/23
# Training batch 7/23
# Training batch 8/23
# Training batch 9/23
# Training batch 10/23
# Training batch 11/23
# Training batch 12/23
# Training batch 13/23
# Training batch 14/23
# Training batch 15/23
# Training batch 16/23
# Training batch 17/23
# Training batch 18/23
# Training batch 19/23
# Training batch 20/23
# Training batch 21/23
# Training batch 22/23
# Training batch 23/23
# Validation batch 1/23
# Validation batch 2/23
# Validation batch 3/23
# Validation batch 4/23
# Validation batch 5/23
# Validation batch 6/23
# Validation batch 7/23
# Validation batch 8/23
# Validation batch 9/23
# Validation batch 10/23
# Validation batch 11/23
# Validation batch 12/23
# Validation batch 13/23
# Validation batch 14/23
# Validation batch 15/23
# Validation batch 16/23
# Validation batch 17/23
# Validation batch 18/23
# Validation batch 19/23
# Validation batch 20/23
# Validation batch 21/23
# Validation batch 22/23
# Validation batch 23/23
# Epoch 25/25 --> Training Loss: 0.0223, Training Accuracy: 100.00%, Validation Loss: 1.2098, Validation Accuracy: 79.71%
#
# Final Results after 25 epochs:
# Training Loss: 0.0223, Training Accuracy: 100.00%
# Validation Loss: 1.2098, Validation Accuracy: 79.71%

# %%
torch.save(clf_model, 'resnet_scratch.pth')

# %%
from PIL import Image

def inference(img_path, transform, yolo_model, clf_model, device):
    img = Image.open(img_path)
    img_tensor = transform(img)

    results = yolo_model(img_tensor)  

    if len(results) > 0:
        bbox = results[0].boxes.xyxy[0] 

        xmin, ymin, xmax, ymax = map(int, bbox)
        cropped_img = img.crop((xmin, ymin, xmax, ymax))

        cropped_img_tensor = transform(cropped_img)
        cropped_img_tensor = cropped_img_tensor.to(device)
        cropped_img_tensor = cropped_img_tensor.unsqueeze(0) 

        output = clf_model(cropped_img_tensor)
        return torch.argmax(output).item()

# %%
img_path = r'cattle muzzle\069\IMG_0906.JPG'
transform = v2.Compose([
    v2.ToTensor(),
    v2.Resize((img_width, img_height))
])
yolo_model = YOLO('yolov10_fine_tuned.pt')
clf_model = torch.load('resnet_transfer_learning.pth')
print(inference(img_path, transform, yolo_model, clf_model, device))
# Out:
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 224, 224) is incompatible.
# 0: 224x224 1 muzzle, 42.2ms
# Speed: 0.0ms preprocess, 42.2ms inference, 4.0ms postprocess per image at shape (1, 3, 224, 224)
# 203
